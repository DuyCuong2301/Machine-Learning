# %%
import numpy as np

W1 = np.random.randn(3, 4)

# %%
print(W1)
# Out:
# [[ 0.01437395  1.48376542  0.53236824 -2.06060567]
#  [ 1.814794    1.1992182  -0.14719807  0.36475933]
#  [-0.46498045  0.38567534  0.54146883 -0.2061314 ]]
